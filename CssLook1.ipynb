# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('seaborn')
plt.rcParams['figure.figsize'] = [20, 7]

# %%
confirmed = pd.read_csv('CSSEGISandData/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')

# %%
deaths = pd.read_csv('CSSEGISandData/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')

# %%
recovered = pd.read_csv('CSSEGISandData/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')

# %%
confirmed
# Out:
#      Province/State      Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0             Anhui      Mainland China  31.8257  117.2264        1        9
# 1           Beijing      Mainland China  40.1824  116.4142       14       22
# 2         Chongqing      Mainland China  30.0572  107.8740        6        9
# 3            Fujian      Mainland China  26.0789  117.9874        1        5
# 4             Gansu      Mainland China  36.0611  103.8343        0        2
# ..              ...                 ...      ...       ...      ...      ...
# 120             NaN          Azerbaijan  40.1431   47.5769        0        0
# 121             NaN      Czech Republic  49.8175   15.4730        0        0
# 122             NaN             Armenia  40.0691   45.0382        0        0
# 123             NaN  Dominican Republic  18.7357  -70.1627        0        0
# 124  Providence, RI                  US  41.8240  -71.4128        0        0
#
# ...

# %%
confirmed2 = confirmed.copy()

# %%
confirmed.rename({'Province/State': 'province', 'Country/Region': 'country'}, axis=1, inplace=True)

# %%
recovered.rename({'Province/State': 'province', 'Country/Region': 'country'}, axis=1, inplace=True)

# %%
deaths.rename({'Province/State': 'province', 'Country/Region': 'country'}, axis=1, inplace=True)

# %%
confirmed[~confirmed['province'].isnull()].country.value_counts()
# Out:
# Mainland China    31
# US                20
# Australia          6
# Canada             4
# Macau              1
# Others             1
# Hong Kong          1
# Taiwan             1
# Name: country, dtype: int64

# %%
confirmed[confirmed['country']=='Hong Kong']
# Out:
#      province    country   Lat   Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 39  Hong Kong  Hong Kong  22.3  114.2        0        2        2        5
#
#     1/26/20  1/27/20  ...  2/21/20  2/22/20  2/23/20  2/24/20  2/25/20  \
# 39        8        8  ...       68       69       74       79       84
#
#     2/26/20  2/27/20  2/28/20  2/29/20  3/1/20
# 39       91       92       94       95      96
#
# [1 rows x 44 columns]

# %%
confirmed[confirmed['country']=='Others']
# Out:
#                         province country      Lat     Long  1/22/20  1/23/20  \
# 71  Diamond Princess cruise ship  Others  35.4437  139.638        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  2/21/20  2/22/20  2/23/20  \
# 71        0        0        0        0  ...      634      634      691
#
#     2/24/20  2/25/20  2/26/20  2/27/20  2/28/20  2/29/20  3/1/20
# 71      691      691      705      705      705      705     705
#
# [1 rows x 44 columns]

# %%
confirmed.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
recovered.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
deaths.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
con = confirmed.groupby('country').sum()

# %%
rec = recovered.groupby('country').sum()

# %%
dea = deaths.groupby('country').sum()

# %%
conf.loc['Italy']
# Out:
# 1/22/20       0
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0
# 1/27/20       0
# 1/28/20       0
# 1/29/20       0
# 1/30/20       0
# 1/31/20       2
# 2/1/20        2
# 2/2/20        2
# 2/3/20        2
# 2/4/20        2
# 2/5/20        2
# 2/6/20        2
# 2/7/20        3
# 2/8/20        3
# 2/9/20        3
# 2/10/20       3
# 2/11/20       3
# 2/12/20       3
# 2/13/20       3
# 2/14/20       3
# 2/15/20       3
# 2/16/20       3
# 2/17/20       3
# 2/18/20       3
# 2/19/20       3
# 2/20/20       3
# 2/21/20      20
# 2/22/20      62
# 2/23/20     155
# 2/24/20     229
# 2/25/20     322
# 2/26/20     453
# 2/27/20     655
# 2/28/20     888
# 2/29/20    1128
# 3/1/20     1694
# Name: Italy, dtype: int64

# %%
conf.loc['Switzerland']
# Out:
# 1/22/20     0
# 1/23/20     0
# 1/24/20     0
# 1/25/20     0
# 1/26/20     0
# 1/27/20     0
# 1/28/20     0
# 1/29/20     0
# 1/30/20     0
# 1/31/20     0
# 2/1/20      0
# 2/2/20      0
# 2/3/20      0
# 2/4/20      0
# 2/5/20      0
# 2/6/20      0
# 2/7/20      0
# 2/8/20      0
# 2/9/20      0
# 2/10/20     0
# 2/11/20     0
# 2/12/20     0
# 2/13/20     0
# 2/14/20     0
# 2/15/20     0
# 2/16/20     0
# 2/17/20     0
# 2/18/20     0
# 2/19/20     0
# 2/20/20     0
# 2/21/20     0
# 2/22/20     0
# 2/23/20     0
# 2/24/20     0
# 2/25/20     1
# 2/26/20     1
# 2/27/20     8
# 2/28/20     8
# 2/29/20    18
# 3/1/20     27
# Name: Switzerland, dtype: int64

# %%
conf.sort_values('3/1/20', ascending=False).head(10)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# country
# Mainland China      547      639      916     1399     2062     2863     5494
# South Korea           1        1        2        2        3        4        4
# Italy                 0        0        0        0        0        0        0
# Iran                  0        0        0        0        0        0        0
# Others                0        0        0        0        0        0        0
# Japan                 2        1        2        2        4        4        7
# Germany               0        0        0        0        0        1        4
# France                0        0        2        3        3        3        4
# Singapore             0        1        3        3        4        5        7
# Hong Kong             0        2        2        5        8        8        8
#
#                 1/29/20  1/30/20  1/31/20  ...  2/21/20  2/22/20  2/23/20  \
# ...

# %%
poplong = pd.read_excel('pop.xls', sheet_name='Data', header=3)

# %%
poplong.rename({'Country Name': 'country'}, axis=1, inplace=True)

# %%
pop = poplong[~poplong['2018'].isnull()][['country','2018']]

# %%
pop.set_index('country', inplace=True)

# %%
pop.reset_index(inplace=True)

# %%
set(conf.index) - set(pop.country)
# Out:
# {'Egypt',
#  'Hong Kong',
#  'Iran',
#  'Macau',
#  'Mainland China',
#  'Others',
#  'Russia',
#  'South Korea',
#  'Taiwan',
#  'UK',
#  'US'}

# %%
pop.country[pop.country.str.contains('Egypt')] = 'Egypt'

# %%
set(conf.index) - set(pop.country)
# Out:
# {'Others', 'Russia', 'South Korea', 'Taiwan', 'UK', 'US'}

# %%
pop.country[pop.country.str.contains('Hong Kong')] = 'Hong Kong'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country == 'China'] = 'Mainland China'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country.str.contains('Iran')] = 'Iran'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country.str.contains('Maca')] = 'Macau'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
popsafe = pop.copy()

# %%
pop = popsafe.copy()

# %%
pop = pop.append({'country' : 'Others', '2018': 3000}, ignore_index=True)

# %%
pop.country[pop.country.str.contains('Russi')] = 'Russia'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country.str.contains('Korea, Dem')] = 'NorthKorea'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country.str.contains('Korea, R')] = 'South Korea'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
set(conf.index) - set(pop.country)
# Out:
# {'Taiwan', 'UK', 'US'}

# %%
pop.country[pop.country.str.contains('United Kingdom')] = 'UK'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pop.country[pop.country.str.contains('United Sta')] = 'US'
# Out:
# /home/acsaba/data/work/data1911/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
set(conf.index) - set(pop.country)
# Out:
# {'Taiwan'}

# %%
pop[pop.country == 'Mainland China']
# Out:
#            country          2018
# 38  Mainland China  1.392730e+09

# %%
pop[pop.country.str.contains('China')]
# Out:
#            country          2018
# 38  Mainland China  1.392730e+09

# %%
pop = pop.append({'country' : 'Taiwan', '2018': 23780000}, ignore_index=True)

# %%
set(conf.index) - set(pop.country)
# Out:
# set()

# %%
popsafe2 = pop.copy()

# %%
pop.set_index('country', inplace=True)

# %%
conf
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# country
# Afghanistan                 0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Armenia                     0        0        0        0        0        0
# Australia                   0        0        0        0        4        5
# Austria                     0        0        0        0        0        0
# ...                       ...      ...      ...      ...      ...      ...
# Thailand                    2        3        5        7        8        8
# UK                          0        0        0        0        0        0
# US                          1        1        2        2        5        5
# United Arab Emirates        0        0        0        0        0        0
# Vietnam                     0        2        2        2        2        2
#
# ...

# %%
conf['3/1/20'] / pop['2018']
# Out:
# country
# Afghanistan           2.690169e-08
# Albania                        NaN
# Algeria               2.368073e-08
# American Samoa                 NaN
# Andorra                        NaN
#                           ...
# West Bank and Gaza             NaN
# World                          NaN
# Yemen, Rep.                    NaN
# Zambia                         NaN
# Zimbabwe                       NaN
# Length: 264, dtype: float64

# %%
popsafe3 = pop

# %%
pop = pop[pop.index.isin(conf.index)]

# %%
(conf.div(pop['2018'], axis=0)*100000).sort_values('3/1/20', ascending=False).head(10)
# Out:
#                  1/22/20   1/23/20   1/24/20   1/25/20   1/26/20   1/27/20  \
# country
# Others          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# South Korea     0.001937  0.001937  0.003873  0.003873  0.005810  0.007747
# Mainland China  0.039275  0.045881  0.065770  0.100450  0.148055  0.205567
# Bahrain         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# San Marino      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Italy           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Monaco          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Singapore       0.000000  0.017735  0.053204  0.053204  0.070939  0.088673
# Macau           0.158319  0.316638  0.316638  0.316638  0.791595  0.949914
# Hong Kong       0.000000  0.026842  0.026842  0.067105  0.107368  0.107368
#
#                  1/28/20   1/29/20   1/30/20   1/31/20  ...       2/21/20  \
# ...

# %%
conf10 = conf[conf['3/1/20'] >= 10]

# %%
conf10 = conf10[~conf10.index.str.contains('Others')]

# %%
(conf10.div(pop['2018'], axis=0)*100000).sort_values('3/1/20', ascending=False).head(10)
# Out:
#                  1/22/20   1/23/20   1/24/20   1/25/20   1/26/20   1/27/20  \
# country
# South Korea     0.001937  0.001937  0.003873  0.003873  0.005810  0.007747
# Mainland China  0.039275  0.045881  0.065770  0.100450  0.148055  0.205567
# Bahrain         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Italy           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Singapore       0.000000  0.017735  0.053204  0.053204  0.070939  0.088673
# Macau           0.158319  0.316638  0.316638  0.316638  0.791595  0.949914
# Hong Kong       0.000000  0.026842  0.026842  0.067105  0.107368  0.107368
# Iran            0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Kuwait          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Norway          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                  1/28/20   1/29/20   1/30/20   1/31/20  ...   2/21/20  \
# country                                                 ...
# ...

# %%
popratio = (conf10.div(pop['2018'], axis=0)*100000).sort_values('3/1/20', ascending=False)

# %%
popratio.head(20).T.plot()

# %%
type(popratio.columns[0])
# Out:
# str

# %%
conf
# Out:
#                        1/22/20   1/23/20   1/24/20   1/25/20   1/26/20  \
# country
# South Korea           0.001937  0.001937  0.003873  0.003873  0.005810
# Mainland China        0.039275  0.045881  0.065770  0.100450  0.148055
# Bahrain               0.000000  0.000000  0.000000  0.000000  0.000000
# Italy                 0.000000  0.000000  0.000000  0.000000  0.000000
# Singapore             0.000000  0.017735  0.053204  0.053204  0.070939
# Macau                 0.158319  0.316638  0.316638  0.316638  0.791595
# Hong Kong             0.000000  0.026842  0.026842  0.067105  0.107368
# Iran                  0.000000  0.000000  0.000000  0.000000  0.000000
# Kuwait                0.000000  0.000000  0.000000  0.000000  0.000000
# Norway                0.000000  0.000000  0.000000  0.000000  0.000000
# Switzerland           0.000000  0.000000  0.000000  0.000000  0.000000
# United Arab Emirates  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
conf.loc['Switzerland']
# Out:
# 1/22/20     0
# 1/23/20     0
# 1/24/20     0
# 1/25/20     0
# 1/26/20     0
# 1/27/20     0
# 1/28/20     0
# 1/29/20     0
# 1/30/20     0
# 1/31/20     0
# 2/1/20      0
# 2/2/20      0
# 2/3/20      0
# 2/4/20      0
# 2/5/20      0
# 2/6/20      0
# 2/7/20      0
# 2/8/20      0
# 2/9/20      0
# 2/10/20     0
# 2/11/20     0
# 2/12/20     0
# 2/13/20     0
# 2/14/20     0
# 2/15/20     0
# 2/16/20     0
# 2/17/20     0
# 2/18/20     0
# 2/19/20     0
# 2/20/20     0
# 2/21/20     0
# 2/22/20     0
# 2/23/20     0
# 2/24/20     0
# 2/25/20     1
# 2/26/20     1
# 2/27/20     8
# 2/28/20     8
# 2/29/20    18
# 3/1/20     27
# Name: Switzerland, dtype: int64

# %%
popsafe3.to_csv('massaged_pop.csv')

# %%
conf10.loc['Italy']
# Out:
# 1/22/20       0
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0
# 1/27/20       0
# 1/28/20       0
# 1/29/20       0
# 1/30/20       0
# 1/31/20       2
# 2/1/20        2
# 2/2/20        2
# 2/3/20        2
# 2/4/20        2
# 2/5/20        2
# 2/6/20        2
# 2/7/20        3
# 2/8/20        3
# 2/9/20        3
# 2/10/20       3
# 2/11/20       3
# 2/12/20       3
# 2/13/20       3
# 2/14/20       3
# 2/15/20       3
# 2/16/20       3
# 2/17/20       3
# 2/18/20       3
# 2/19/20       3
# 2/20/20       3
# 2/21/20      20
# 2/22/20      62
# 2/23/20     155
# 2/24/20     229
# 2/25/20     322
# 2/26/20     453
# 2/27/20     655
# 2/28/20     888
# 2/29/20    1128
# 3/1/20     1694
# Name: Italy, dtype: int64
